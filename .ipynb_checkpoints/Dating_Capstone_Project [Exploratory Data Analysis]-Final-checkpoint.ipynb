# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from datetime import datetime
import re

# %%
#Make a copy of the dataset so we have all the original information as we manipulate columns and values

df = pd.read_csv('cc_capstone/profiles.csv')
df_copy = df.copy()

# %%
df_copy.columns

# %% [markdown]
# ## Create a new dataframe with non-essay columns

# %%
df_chars = df_copy[['age', 'body_type', 'diet', 'drinks', 'drugs', 'education', 'ethnicity', 'height', 'income', 'job',
                   'last_online', 'location', 'offspring', 'orientation', 'pets', 'religion', 'sex', 'sign', 'smokes', 
                   'speaks', 'status']]
df_chars.head()
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   35         average       mostly other     often  sometimes
# 2   38            thin           anything  socially        NaN
# 3   23            thin         vegetarian  socially        NaN
# 4   29        athletic                NaN  socially      never
#
#                            education            ethnicity  height  income  \
# 0      working on college/university         asian, white    75.0      -1
# 1              working on space camp                white    70.0   80000
# 2     graduated from masters program                  NaN    68.0      -1
# 3      working on college/university                white    71.0   20000
# 4  graduated from college/university  asian, black, other    66.0      -1
#
#                            job  ...                         location  \
# 0               transportation  ...  south san francisco, california
# 1         hospitality / travel  ...              oakland, california
# 2                          NaN  ...        san francisco, california
# 3                      student  ...             berkeley, california
# 4  artistic / musical / writer  ...        san francisco, california
#
#                                       offspring orientation  \
# 0  doesn&rsquo;t have kids, but might want them    straight
# 1  doesn&rsquo;t have kids, but might want them    straight
# 2                                           NaN    straight
# 3                       doesn&rsquo;t want kids    straight
# 4                                           NaN    straight
#
#                         pets                                  religion sex  \
# 0  likes dogs and likes cats     agnosticism and very serious about it   m
# 1  likes dogs and likes cats  agnosticism but not too serious about it   m
# 2                   has cats                                       NaN   m
# 3                 likes cats                                       NaN   m
# 4  likes dogs and likes cats                                       NaN   m
#
#                                  sign     smokes  \
# 0                              gemini  sometimes
# 1                              cancer         no
# 2  pisces but it doesn&rsquo;t matter         no
# 3                              pisces         no
# 4                            aquarius         no
#
#                                               speaks     status
# 0                                            english     single
# 1  english (fluently), spanish (poorly), french (...     single
# 2                               english, french, c++  available
# 3                           english, german (poorly)     single
# 4                                            english     single
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Summarize and get a feel for the data
# - Find how many samples exist in the dataset
# - Understand data type of each feature and how to best manipulate it to suit our interest
# (df.info is more comprehensive than df.dtypes)

# %%
df_features = df_copy.columns
print(df_features)
df_features.size
df.info()
# Out:
# Index(['age', 'body_type', 'diet', 'drinks', 'drugs', 'education', 'essay0',
#        'essay1', 'essay2', 'essay3', 'essay4', 'essay5', 'essay6', 'essay7',
#        'essay8', 'essay9', 'ethnicity', 'height', 'income', 'job',
#        'last_online', 'location', 'offspring', 'orientation', 'pets',
#        'religion', 'sex', 'sign', 'smokes', 'speaks', 'status'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   body_type    54650 non-null  object
#  2   diet         35551 non-null  object
#  3   drinks       56961 non-null  object
#  4   drugs        45866 non-null  object
#  5   education    53318 non-null  object
#  6   essay0       54458 non-null  object
#  7   essay1       52374 non-null  object
#  8   essay2       50308 non-null  object
#  9   essay3       48470 non-null  object
#  10  essay4       49409 non-null  object
#  11  essay5       49096 non-null  object
#  12  essay6       46175 non-null  object
#  13  essay7       47495 non-null  object
#  14  essay8       40721 non-null  object
#  15  essay9       47343 non-null  object
#  16  ethnicity    54266 non-null  object
#  17  height       59943 non-null  float64
#  18  income       59946 non-null  int64
#  19  job          51748 non-null  object
#  20  last_online  59946 non-null  object
#  21  location     59946 non-null  object
#  22  offspring    24385 non-null  object
#  23  orientation  59946 non-null  object
#  24  pets         40025 non-null  object
#  25  religion     39720 non-null  object
#  26  sex          59946 non-null  object
#  27  sign         48890 non-null  object
#  28  smokes       54434 non-null  object
#  29  speaks       59896 non-null  object
#  30  status       59946 non-null  object
# dtypes: float64(1), int64(2), object(28)
# memory usage: 14.2+ MB

# %%
df_copy.shape
#Almost 60,000 observations!
# Out:
# (59946, 31)

# %% [markdown]
# ## Correlation Table between numeric data -- Encode all other features

# %%
df_chars.corr()
# Out:
#              age    height    income
# age     1.000000 -0.022262 -0.001004
# height -0.022262  1.000000  0.065049
# income -0.001004  0.065049  1.000000

# %%
df.age.describe()
# Out:
# count    59946.000000
# mean        32.340290
# std          9.452779
# min         18.000000
# 25%         26.000000
# 50%         30.000000
# 75%         37.000000
# max        110.000000
# Name: age, dtype: float64

# %%
df.height.describe()
# Out:
# count    59943.000000
# mean        68.295281
# std          3.994803
# min          1.000000
# 25%         66.000000
# 50%         68.000000
# 75%         71.000000
# max         95.000000
# Name: height, dtype: float64

# %%
df_copy.income.describe()
# Out:
# count      59946.000000
# mean       20033.222534
# std        97346.192104
# min           -1.000000
# 25%           -1.000000
# 50%           -1.000000
# 75%           -1.000000
# max      1000000.000000
# Name: income, dtype: float64

# %%
df_copy.income.value_counts()
unreported = (59946 - 48442)/(59946)*100

# %%
print("With only {x:.2f}% of data NOT EQUAL to -1 & avaiable, one should DROP the feature.".format(x = unreported))
# Out:
# With only 19.19% of data NOT EQUAL to -1 & avaiable, one should DROP the feature.

# %% [markdown]
# ## Create a drop list and append as you find features that should be dropped

# %%
init_drop_cols = ['income']

# %%
nonnum_df = df_chars.drop(['age', 'height', 'income'], axis = 1)
nonnum_df.head(3)
# Out:
#         body_type               diet    drinks      drugs  \
# 0  a little extra  strictly anything  socially      never
# 1         average       mostly other     often  sometimes
# 2            thin           anything  socially        NaN
#
#                         education     ethnicity                   job  \
# 0   working on college/university  asian, white        transportation
# 1           working on space camp         white  hospitality / travel
# 2  graduated from masters program           NaN                   NaN
#
#         last_online                         location  \
# 0  2012-06-28-20-30  south san francisco, california
# 1  2012-06-29-21-41              oakland, california
# 2  2012-06-27-09-10        san francisco, california
#
#                                       offspring orientation  \
# 0  doesn&rsquo;t have kids, but might want them    straight
# 1  doesn&rsquo;t have kids, but might want them    straight
# 2                                           NaN    straight
#
#                         pets                                  religion sex  \
# 0  likes dogs and likes cats     agnosticism and very serious about it   m
# 1  likes dogs and likes cats  agnosticism but not too serious about it   m
# 2                   has cats                                       NaN   m
#
#                                  sign     smokes  \
# 0                              gemini  sometimes
# 1                              cancer         no
# 2  pisces but it doesn&rsquo;t matter         no
#
#                                               speaks     status
# 0                                            english     single
# 1  english (fluently), spanish (poorly), french (...     single
# 2                               english, french, c++  available

# %% [markdown]
# ## Treat Status as Target Feature

# %%
df_chars.status.unique()
# Out:
# array(['single', 'available', 'seeing someone', 'married', 'unknown'],
#       dtype=object)

# %%
df_chars.status.value_counts()
# Out:
# single            55697
# seeing someone     2064
# available          1865
# married             310
# unknown              10
# Name: status, dtype: int64

# %% [markdown]
# ### Action Items for 'Status' column
# - <b/>Create</b> Single: 'single' + 'available'
# - <b/>Create</b> Taken: 'seeing someone'
# - <b/>Remove</b>: 'married' + 'unknown'

# %% [markdown]
# # Definitions and thoughts -- in an accompanied Google Sheets
# - body_type:
# - diet:
# - drinks:
# - drugs:
# - education:
#
# - ethnicity:
# - height:
# - income:
# - job:
# - offspring:
# - orientation:
# - pets:
# - religion:
# - sex:
# - sign:
# - smokes:
# - speaks:
# - status:

# %% [markdown]
# # Find the amount of missing data by feature

# %%
def draw_missing_data_table(df):
    total = df.isnull().sum().sort_values(ascending = False)
    percent = (df.isnull().sum()/ df.isnull().count()).sort_values(ascending = False)
    missing_data = pd.concat([total, percent], axis = 1, keys = ['Total','Percent Missing'])
    return missing_data

# %%
draw_missing_data_table(df_copy)
# Out:
#              Total  Percent Missing
# offspring    35561         0.593217
# diet         24395         0.406950
# religion     20226         0.337404
# pets         19921         0.332316
# essay8       19225         0.320705
# drugs        14080         0.234878
# essay6       13771         0.229723
# essay9       12603         0.210239
# essay7       12451         0.207704
# essay3       11476         0.191439
# sign         11056         0.184433
# essay5       10850         0.180996
# essay4       10537         0.175775
# essay2        9638         0.160778
# job           8198         0.136756
# essay1        7572         0.126314
# education     6628         0.110566
# ethnicity     5680         0.094752
# smokes        5512         0.091949
# essay0        5488         0.091549
# body_type     5296         0.088346
# drinks        2985         0.049795
# speaks          50         0.000834
# height           3         0.000050
# status           0         0.000000
# income           0         0.000000
# last_online      0         0.000000
# location         0         0.000000
# orientation      0         0.000000
# sex              0         0.000000
# age              0         0.000000

# %% [markdown]
# ### Drop Features with insufficient data; later build or average values for NA
# - offspring
# - diet
# - **pets**

# %%
init_drop_cols.append(['offspring', 'diet', 'religion'])

# %%
essay_cols = ['essay0', 'essay1', 'essay2', 'essay3', 'essay4', 'essay5', 'essay6', 'essay7', 'essay8', 'essay9']

# %%
essay_dat = {'Essay Summary': ["My self summary", 
             "What I’m doing with my life", 
             "I’m really good at",
             "The first thing people usually notice about me",
             "Favorite books, movies, show, music, and food",
             "The six things I could never do without",
             "I spend a lot of time thinking about",
             "On a typical Friday night I am",
             "The most private thing I am willing to admit",
             "You should message me if…"]}

# %%
essay_missing = draw_missing_data_table(df_copy).loc[essay_cols, :]
essay_missing
# Out:
#         Total  Percent Missing
# essay0   5488         0.091549
# essay1   7572         0.126314
# essay2   9638         0.160778
# essay3  11476         0.191439
# essay4  10537         0.175775
# essay5  10850         0.180996
# essay6  13771         0.229723
# essay7  12451         0.207704
# essay8  19225         0.320705
# essay9  12603         0.210239

# %%
essay_summary = pd.DataFrame(data = essay_dat, index = essay_cols)
essay_summary = essay_summary.join(essay_missing)
essay_summary.sort_values(by = 'Percent Missing', ascending = False)
# Out:
#                                          Essay Summary  Total  Percent Missing
# essay8    The most private thing I am willing to admit  19225         0.320705
# essay6            I spend a lot of time thinking about  13771         0.229723
# essay9                       You should message me if…  12603         0.210239
# essay7                  On a typical Friday night I am  12451         0.207704
# essay3  The first thing people usually notice about me  11476         0.191439
# essay5         The six things I could never do without  10850         0.180996
# essay4   Favorite books, movies, show, music, and food  10537         0.175775
# essay2                              I’m really good at   9638         0.160778
# essay1                     What I’m doing with my life   7572         0.126314
# essay0                                 My self summary   5488         0.091549

# %% [markdown]
# ## Create dataframe without Essay Columns

# %%
non_essay_feats = df_copy[df_copy.columns.difference(essay_cols)]
non_essay_feats.head(3)
# Out:
#    age       body_type               diet    drinks      drugs  \
# 0   22  a little extra  strictly anything  socially      never
# 1   35         average       mostly other     often  sometimes
# 2   38            thin           anything  socially        NaN
#
#                         education     ethnicity  height  income  \
# 0   working on college/university  asian, white    75.0      -1
# 1           working on space camp         white    70.0   80000
# 2  graduated from masters program           NaN    68.0      -1
#
#                     job  ...                         location  \
# 0        transportation  ...  south san francisco, california
# 1  hospitality / travel  ...              oakland, california
# 2                   NaN  ...        san francisco, california
#
#                                       offspring orientation  \
# 0  doesn&rsquo;t have kids, but might want them    straight
# 1  doesn&rsquo;t have kids, but might want them    straight
# 2                                           NaN    straight
#
#                         pets                                  religion sex  \
# 0  likes dogs and likes cats     agnosticism and very serious about it   m
# 1  likes dogs and likes cats  agnosticism but not too serious about it   m
# 2                   has cats                                       NaN   m
#
#                                  sign     smokes  \
# 0                              gemini  sometimes
# 1                              cancer         no
# 2  pisces but it doesn&rsquo;t matter         no
#
#                                               speaks     status
# 0                                            english     single
# 1  english (fluently), spanish (poorly), french (...     single
# 2                               english, french, c++  available
#
# [3 rows x 21 columns]

# %%
init_drop_cols
# Out:
# ['income', ['offspring', 'diet', 'religion']]

# %%
non_essay_feats = non_essay_feats[non_essay_feats.columns.difference(['income', 'offspring', 'diet'])]
non_essay_feats
# Out:
#        age       body_type      drinks      drugs  \
# 0       22  a little extra    socially      never
# 1       35         average       often  sometimes
# 2       38            thin    socially        NaN
# 3       23            thin    socially        NaN
# 4       29        athletic    socially      never
# ...    ...             ...         ...        ...
# 59941   59             NaN    socially      never
# 59942   24             fit       often  sometimes
# 59943   42         average  not at all      never
# 59944   27        athletic    socially      often
# 59945   39         average    socially        NaN
#
#                                education            ethnicity  height  \
# 0          working on college/university         asian, white    75.0
# 1                  working on space camp                white    70.0
# 2         graduated from masters program                  NaN    68.0
# 3          working on college/university                white    71.0
# 4      graduated from college/university  asian, black, other    66.0
# ...                                  ...                  ...     ...
# 59941  graduated from college/university                  NaN    62.0
# 59942      working on college/university         white, other    72.0
# 59943     graduated from masters program                asian    71.0
# 59944      working on college/university         asian, black    73.0
# 59945     graduated from masters program                white    68.0
#
#                                 job       last_online  \
# 0                    transportation  2012-06-28-20-30
# 1              hospitality / travel  2012-06-29-21-41
# 2                               NaN  2012-06-27-09-10
# 3                           student  2012-06-28-14-22
# 4       artistic / musical / writer  2012-06-27-21-26
# ...                             ...               ...
# 59941   sales / marketing / biz dev  2012-06-12-21-47
# 59942         entertainment / media  2012-06-29-11-01
# 59943  construction / craftsmanship  2012-06-27-23-37
# 59944             medicine / health  2012-06-23-13-01
# 59945             medicine / health  2012-06-29-00-42
#
#                               location orientation                       pets  \
# 0      south san francisco, california    straight  likes dogs and likes cats
# 1                  oakland, california    straight  likes dogs and likes cats
# 2            san francisco, california    straight                   has cats
# 3                 berkeley, california    straight                 likes cats
# 4            san francisco, california    straight  likes dogs and likes cats
# ...                                ...         ...                        ...
# 59941              oakland, california    straight                   has dogs
# 59942        san francisco, california    straight  likes dogs and likes cats
# 59943  south san francisco, california    straight                        NaN
# 59944        san francisco, california    straight  likes dogs and likes cats
# 59945        san francisco, california         gay  likes dogs and likes cats
#
#                                         religion sex  \
# 0          agnosticism and very serious about it   m
# 1       agnosticism but not too serious about it   m
# 2                                            NaN   m
# 3                                            NaN   m
# 4                                            NaN   m
# ...                                          ...  ..
# 59941   catholicism but not too serious about it   f
# 59942                                agnosticism   m
# 59943  christianity but not too serious about it   m
# 59944   agnosticism but not too serious about it   m
# 59945          catholicism and laughing about it   m
#
#                                            sign          smokes  \
# 0                                        gemini       sometimes
# 1                                        cancer              no
# 2            pisces but it doesn&rsquo;t matter              no
# 3                                        pisces              no
# 4                                      aquarius              no
# ...                                         ...             ...
# 59941  cancer and it&rsquo;s fun to think about              no
# 59942           leo but it doesn&rsquo;t matter              no
# 59943   sagittarius but it doesn&rsquo;t matter              no
# 59944     leo and it&rsquo;s fun to think about  trying to quit
# 59945  gemini and it&rsquo;s fun to think about       sometimes
#
#                                                   speaks     status
# 0                                                english     single
# 1      english (fluently), spanish (poorly), french (...     single
# 2                                   english, french, c++  available
# 3                               english, german (poorly)     single
# 4                                                english     single
# ...                                                  ...        ...
# 59941                                            english     single
# 59942                                 english (fluently)     single
# 59943                                 english (fluently)     single
# 59944  english (fluently), spanish (poorly), chinese ...     single
# 59945                                            english     single
#
# [59946 rows x 18 columns]

# %% [markdown]
# ## Create a table to explore features you haven't already

# %%
feats_to_explore = non_essay_feats[non_essay_feats.columns.difference(['age', 
                                                                       'height', 
                                                                       'last_online', 
                                                                       'location', 
                                                                       'orientation', 
                                                                       'sex',])]
feats_to_explore.head(4)
# Out:
#         body_type    drinks      drugs                       education  \
# 0  a little extra  socially      never   working on college/university
# 1         average     often  sometimes           working on space camp
# 2            thin  socially        NaN  graduated from masters program
# 3            thin  socially        NaN   working on college/university
#
#       ethnicity                   job                       pets  \
# 0  asian, white        transportation  likes dogs and likes cats
# 1         white  hospitality / travel  likes dogs and likes cats
# 2           NaN                   NaN                   has cats
# 3         white               student                 likes cats
#
#                                    religion  \
# 0     agnosticism and very serious about it
# 1  agnosticism but not too serious about it
# 2                                       NaN
# 3                                       NaN
#
#                                  sign     smokes  \
# 0                              gemini  sometimes
# 1                              cancer         no
# 2  pisces but it doesn&rsquo;t matter         no
# 3                              pisces         no
#
#                                               speaks     status
# 0                                            english     single
# 1  english (fluently), spanish (poorly), french (...     single
# 2                               english, french, c++  available
# 3                           english, german (poorly)     single

# %%
numfeats2encode_df = nonnum_df[['body_type', 'drinks', 'drugs', 'education', 'smokes']]
catfeats2encode_df = nonnum_df[['diet', 'ethnicity', 'job', 'location', 'offspring',
                                'orientation', 'pets', 'religion', 'sign', 'speaks' ]] 
#include cat feature whether currently in education

# %% [markdown]
# ### Create user_id column for each row; helps to group data by

# %%
df_copy['user_id'] = range(len(df))
df_copy.tail()

# %% [markdown]
# # Split Location data
# -> City and State Features
# <br />
# then ->: California and Other States

# %%
location_table = df_copy.location.str.split(pat = ',', expand = True)
del location_table[2]
location_table.rename(columns = {0: 'City', 1: 'State'}, inplace = True)
print(location_table)
# Out:
#                       City        State
# 0      south san francisco   california
# 1                  oakland   california
# 2            san francisco   california
# 3                 berkeley   california
# 4            san francisco   california
# ...                    ...          ...
# 59941              oakland   california
# 59942        san francisco   california
# 59943  south san francisco   california
# 59944        san francisco   california
# 59945        san francisco   california
#
# [59946 rows x 2 columns]

# %% [markdown]
# ## Create a Table of the Total Survey Respondants by Unique Cities

# %%
type(location_table['City'].unique())
# Out:
# numpy.ndarray

# %%
cities = location_table.City
(unq_city, city_count) = np.unique(cities, return_counts = True)
unique_freq = np.asarray((unq_city, city_count)).T
unique_freq.sort(axis = 0)
unique_freq
# Out:
# array([['alameda', 1],
#        ['albany', 1],
#        ['amsterdam', 1],
#        ['arcadia', 1],
#        ['asheville', 1],
#        ['ashland', 1],
#        ['astoria', 1],
#        ['atherton', 1],
#        ['atlanta', 1],
#        ['austin', 1],
#        ['bayshore', 1],
#        ['bellingham', 1],
#        ['bellwood', 1],
#        ['belmont', 1],
#        ['belvedere tiburon', 1],
#        ['benicia', 1],
#        ['berkeley', 1],
#        ['billings', 1],
#        ['boise', 1],
#        ['bolinas', 1],
#        ['bonaduz', 1],
#        ['boston', 1],
#        ['boulder', 1],
#        ['brea', 1],
#        ['brisbane', 1],
#        ['brooklyn', 1],
#        ['burlingame', 1],
#        ['cambridge', 1],
#        ['campbell', 1],
#        ['canyon', 1],
#        ['canyon country', 1],
#        ['castro valley', 1],
#        ['chicago', 1],
#        ['chico', 1],
#        ['cincinnati', 1],
#        ['colma', 1],
#        ['columbus', 1],
#        ['concord', 1],
#        ['cork', 1],
#        ['corte madera', 1],
#        ['costa mesa', 1],
#        ['crockett', 1],
#        ['crowley', 1],
#        ['daly city', 1],
#        ['denver', 1],
#        ['east palo alto', 1],
#        ['edinburgh', 1],
#        ['el cerrito', 1],
#        ['el granada', 1],
#        ['el sobrante', 1],
#        ['emeryville', 1],
#        ['fairfax', 1],
#        ['fayetteville', 1],
#        ['forest knolls', 1],
#        ['fort lauderdale', 1],
#        ['foster city', 1],
#        ['freedom', 1],
#        ['fremont', 1],
#        ['glencove', 1],
#        ['grand rapids', 1],
#        ['granite bay', 1],
#        ['green brae', 1],
#        ['guadalajara', 1],
#        ['hacienda heights', 1],
#        ['half moon bay', 1],
#        ['hayward', 1],
#        ['hercules', 1],
#        ['hilarita', 1],
#        ['hillsborough', 1],
#        ['honolulu', 1],
#        ['irvine', 1],
#        ['isla vista', 1],
#        ['islip terrace', 1],
#        ['jackson', 1],
#        ['kansas city', 1],
#        ['kassel', 1],
#        ['kensington', 1],
#        ['kentfield', 1],
#        ['kula', 1],
#        ['lafayette', 1],
#        ['lagunitas', 1],
#        ['lake orion', 1],
#        ['larkspur', 1],
#        ['las vegas', 1],
#        ['leander', 1],
#        ['livingston', 1],
#        ['london', 1],
#        ['long beach', 1],
#        ['longwood', 1],
#        ['los angeles', 1],
#        ['los gatos', 1],
#        ['madrid', 1],
#        ['magalia', 1],
#        ['marin city', 1],
#        ['martinez', 2],
#        ['menlo park', 2],
#        ['miami', 2],
#        ['mill valley', 2],
#        ['millbrae', 2],
#        ['milpitas', 2],
#        ['milwaukee', 2],
#        ['minneapolis', 2],
#        ['modesto', 2],
#        ['montara', 2],
#        ['moraga', 2],
#        ['moss beach', 2],
#        ['mountain view', 2],
#        ['muir beach', 2],
#        ['murfreesboro', 2],
#        ['napa', 2],
#        ['nevada city', 2],
#        ['new orleans', 2],
#        ['new york', 2],
#        ['nha trang', 2],
#        ['nicasio', 3],
#        ['north hollywood', 3],
#        ['novato', 3],
#        ['oakland', 3],
#        ['oakley', 4],
#        ['oceanview', 4],
#        ['olema', 4],
#        ['orange', 5],
#        ['orinda', 5],
#        ['ozone park', 6],
#        ['pacheco', 6],
#        ['pacifica', 7],
#        ['palo alto', 7],
#        ['pasadena', 8],
#        ['peoria', 8],
#        ['petaluma', 8],
#        ['philadelphia', 9],
#        ['phoenix', 10],
#        ['piedmont', 10],
#        ['pinole', 10],
#        ['pleasant hill', 11],
#        ['point richmond', 11],
#        ['port costa', 12],
#        ['portland', 12],
#        ['providence', 12],
#        ['redwood city', 13],
#        ['redwood shores', 16],
#        ['richmond', 18],
#        ['riverside', 24],
#        ['rochester', 27],
#        ['rodeo', 32],
#        ['rohnert park', 37],
#        ['ross', 38],
#        ['sacramento', 45],
#        ['salt lake city', 57],
#        ['san anselmo', 76],
#        ['san antonio', 80],
#        ['san bruno', 84],
#        ['san carlos', 85],
#        ['san diego', 87],
#        ['san francisco', 90],
#        ['san geronimo', 99],
#        ['san jose', 104],
#        ['san leandro', 117],
#        ['san lorenzo', 121],
#        ['san luis obispo', 135],
#        ['san mateo', 137],
#        ['san pablo', 147],
#        ['san quentin', 155],
#        ['san rafael', 179],
#        ['santa ana', 180],
#        ['santa clara', 203],
#        ['santa cruz', 227],
#        ['santa monica', 233],
#        ['santa rosa', 243],
#        ['sausalito', 245],
#        ['seaside', 290],
#        ['seattle', 315],
#        ['south lake tahoe', 316],
#        ['south orange', 323],
#        ['south san francisco', 325],
#        ['south wellfleet', 341],
#        ['stanford', 345],
#        ['stinson beach', 347],
#        ['stockton', 361],
#        ['stratford', 369],
#        ['studio city', 384],
#        ['sunnyvale', 416],
#        ['taunton', 424],
#        ['tiburon', 479],
#        ['tucson', 558],
#        ['union city', 644],
#        ['utica', 651],
#        ['vacaville', 681],
#        ['vallejo', 693],
#        ['vancouver', 738],
#        ['walnut creek', 747],
#        ['washington', 755],
#        ['waterford', 910],
#        ['west oakland', 1064],
#        ['westlake', 1331],
#        ['woodacre', 4212],
#        ['woodbridge', 7214],
#        ['woodside', 31064]], dtype=object)

# %%
y = pd.DataFrame(unique_freq)
y.sort_values(by = 1, ascending = False).reset_index()
y.columns = ['City', 'Survey Count']
z = y.sort_values(by = 'Survey Count', ascending = False).reset_index(drop = True) #drop attribute removes the index
z
# Out:
#              City Survey Count
# 0        woodside        31064
# 1      woodbridge         7214
# 2        woodacre         4212
# 3        westlake         1331
# 4    west oakland         1064
# ..            ...          ...
# 193      hercules            1
# 194      hilarita            1
# 195  hillsborough            1
# 196      honolulu            1
# 197       alameda            1
#
# [198 rows x 2 columns]

# %%
z["Cummulative Sum"] = z['Survey Count'].cumsum()
z
# Out:
#              City Survey Count Cummulative Sum
# 0        woodside        31064           31064
# 1      woodbridge         7214           38278
# 2        woodacre         4212           42490
# 3        westlake         1331           43821
# 4    west oakland         1064           44885
# ..            ...          ...             ...
# 193      hercules            1           59942
# 194      hilarita            1           59943
# 195  hillsborough            1           59944
# 196      honolulu            1           59945
# 197       alameda            1           59946
#
# [198 rows x 3 columns]

# %% [markdown]
# #### Create a Percent of Total Survey column

# %%
z["Percent of Total Survey Respondants"] = z['Cummulative Sum']/ z['Cummulative Sum'][197]*100
z
# Out:
#              City Survey Count Cummulative Sum  \
# 0        woodside        31064           31064
# 1      woodbridge         7214           38278
# 2        woodacre         4212           42490
# 3        westlake         1331           43821
# 4    west oakland         1064           44885
# ..            ...          ...             ...
# 193      hercules            1           59942
# 194      hilarita            1           59943
# 195  hillsborough            1           59944
# 196      honolulu            1           59945
# 197       alameda            1           59946
#
#     Percent of Total Survey Respondants
# 0                                 51.82
# 1                               63.8541
# 2                               70.8805
# 3                               73.1008
# 4                               74.8757
# ..                                  ...
# 193                             99.9933
# 194                              99.995
# 195                             99.9967
# 196                             99.9983
# 197                                 100
#
# [198 rows x 4 columns]

# %% [markdown]
# ### By reducing the variety of locations by 134 one only removes 0.5% of the Survey Respondants !

# %%
neglig_data = z[z.index > 63]
neglig_data["Survey Count"].sum()
neglig_data
# Out:
#              City Survey Count Cummulative Sum  \
# 64         pinole           10           59699
# 65       piedmont           10           59709
# 66        phoenix           10           59719
# 67   philadelphia            9           59728
# 68         peoria            8           59736
# ..            ...          ...             ...
# 193      hercules            1           59942
# 194      hilarita            1           59943
# 195  hillsborough            1           59944
# 196      honolulu            1           59945
# 197       alameda            1           59946
#
#     Percent of Total Survey Respondants
# 64                               99.588
# 65                              99.6046
# 66                              99.6213
# 67                              99.6363
# 68                              99.6497
# ..                                  ...
# 193                             99.9933
# 194                              99.995
# 195                             99.9967
# 196                             99.9983
# 197                                 100
#
# [134 rows x 4 columns]

# %% [markdown]
# ### Find the Count of the Unique states

# %%
states = location_table.State
(unq_state, state_count) = np.unique(states, return_counts = True)
unique_states = np.asarray((unq_state, state_count)).T
unique_states
# Out:
# array([[' arizona', 3],
#        [' british columbia', 1],
#        [' california', 59855],
#        [' colorado', 2],
#        [' connecticut', 1],
#        [' district of columbia', 2],
#        [' florida', 3],
#        [' georgia', 2],
#        [' germany', 1],
#        [' hawaii', 2],
#        [' idaho', 1],
#        [' illinois', 8],
#        [' ireland', 1],
#        [' louisiana', 1],
#        [' massachusetts', 5],
#        [' mexico', 1],
#        [' michigan', 4],
#        [' minnesota', 2],
#        [' mississippi', 1],
#        [' missouri', 1],
#        [' montana', 1],
#        [' netherlands', 1],
#        [' nevada', 1],
#        [' new jersey', 1],
#        [' new york', 17],
#        [' north carolina', 1],
#        [' ohio', 2],
#        [' oregon', 4],
#        [' pennsylvania', 1],
#        [' rhode island', 1],
#        [' spain', 2],
#        [' switzerland', 1],
#        [' tennessee', 1],
#        [' texas', 4],
#        [' united kingdom', 2],
#        [' utah', 2],
#        [' vietnam', 1],
#        [' virginia', 2],
#        [' washington', 2],
#        [' west virginia', 1],
#        [' wisconsin', 1]], dtype=object)

# %%
z = pd.DataFrame(unique_states)
z.sort_values(by = 1, ascending = False).reset_index()
z.columns = ['State', 'Survey Count']
z.sort_values(by = 'Survey Count', ascending = False).reset_index(drop = True) #drop attribute removes the index
# Out:
#                     State Survey Count
# 0              california        59855
# 1                new york           17
# 2                illinois            8
# 3           massachusetts            5
# 4                  oregon            4
# 5                   texas            4
# 6                michigan            4
# 7                 arizona            3
# 8                 florida            3
# 9              washington            2
# 10         united kingdom            2
# 11               colorado            2
# 12                  spain            2
# 13                 hawaii            2
# 14   district of columbia            2
# 15              minnesota            2
# 16                   ohio            2
# 17                georgia            2
# 18               virginia            2
# 19                   utah            2
# 20                vietnam            1
# 21          west virginia            1
# 22              tennessee            1
# 23            switzerland            1
# 24           rhode island            1
# 25           pennsylvania            1
# 26                montana            1
# 27         north carolina            1
# 28             new jersey            1
# 29                 nevada            1
# 30            netherlands            1
# 31       british columbia            1
# 32               missouri            1
# 33            mississippi            1
# 34                 mexico            1
# 35              louisiana            1
# 36                ireland            1
# 37                  idaho            1
# 38                germany            1
# 39            connecticut            1
# 40              wisconsin            1

# %%
''' Select Rows in the dataFrame that only contain California as a location'''
non_essay_feats = non_essay_feats[non_essay_feats.location.str.contains('california')]
non_essay_feats.location #Notice the length matches the Survey Count found above
# Out:
# 0        south san francisco, california
# 1                    oakland, california
# 2              san francisco, california
# 3                   berkeley, california
# 4              san francisco, california
#                       ...
# 59941                oakland, california
# 59942          san francisco, california
# 59943    south san francisco, california
# 59944          san francisco, california
# 59945          san francisco, california
# Name: location, Length: 59855, dtype: object

# %% [markdown]
# ## Notice some Surveys are from outside the COUNTRY - not just the state:
# - United Kingdom (2)
# - Spain (2)
# - Vietnam (1)
# - Switzerland (1)
# - Netherlands (1)
# - Brittish Columbia (1)
# - Ireland (1)
# - Germany (1)<br>**TOTAL: 10**

# %% [markdown]
# ## Timeframe of the Data:
#  + 2011 - 2012
#  + End of June to Beginning of July (~Essentially JULY2011 - July2012)

# %%
df_copy['last_online'] = df_copy['last_online'].astype('string') # Change dtype to a string to convert into Datetime
df_copy.last_online
# Out:
# 0        2012-06-28-20-30
# 1        2012-06-29-21-41
# 2        2012-06-27-09-10
# 3        2012-06-28-14-22
# 4        2012-06-27-21-26
#                ...
# 59941    2012-06-12-21-47
# 59942    2012-06-29-11-01
# 59943    2012-06-27-23-37
# 59944    2012-06-23-13-01
# 59945    2012-06-29-00-42
# Name: last_online, Length: 59946, dtype: string

# %% [markdown]
# ### Create a datetime object to parse the last_online values

# %%
df_copy['last_online'] = pd.to_datetime(df['last_online'], format = "%Y-%m-%d-%H-%M")
df_copy.last_online #access datetime features w/ df.feature.dt.____(month, date, time, etc.)
# Out:
# 0       2012-06-28 20:30:00
# 1       2012-06-29 21:41:00
# 2       2012-06-27 09:10:00
# 3       2012-06-28 14:22:00
# 4       2012-06-27 21:26:00
#                 ...
# 59941   2012-06-12 21:47:00
# 59942   2012-06-29 11:01:00
# 59943   2012-06-27 23:37:00
# 59944   2012-06-23 13:01:00
# 59945   2012-06-29 00:42:00
# Name: last_online, Length: 59946, dtype: datetime64[ns]

# %% [markdown]
# ## Create a Table of Dates and Times that users Logged on

# %%
dt_table = pd.DataFrame()
dt_table['Date'] = df_copy['last_online'].dt.date
dt_table['Time'] = df_copy['last_online'].dt.time
sorted = dt_table.sort_values(by = 'Date')
sorted
# Out:
#              Date      Time
# 48850  2011-06-27  19:22:00
# 9849   2011-06-27  08:22:00
# 16219  2011-06-27  18:19:00
# 57254  2011-06-27  14:18:00
# 30652  2011-06-27  23:21:00
# ...           ...       ...
# 55568  2012-07-01  04:09:00
# 55577  2012-07-01  01:27:00
# 46300  2012-07-01  01:27:00
# 55591  2012-07-01  07:14:00
# 50985  2012-07-01  00:13:00
#
# [59946 rows x 2 columns]

# %%
dt_table['Time'] # under 24 hr time
# Out:
# 0        20:30:00
# 1        21:41:00
# 2        09:10:00
# 3        14:22:00
# 4        21:26:00
#            ...
# 59941    21:47:00
# 59942    11:01:00
# 59943    23:37:00
# 59944    13:01:00
# 59945    00:42:00
# Name: Time, Length: 59946, dtype: object

# %% [markdown]
# ### Find the most Frequent Hours users logged on

# %%
hours = [dt_table.Time[x].hour for x in range(len(dt_table.Time))]

# %% [markdown]
# ## Create a function to count the Hour occurences from the times list

# %%
def countFreq(list):
    freq_dic = {}
    for hour in list:
        freq_dic[hour] = list.count(hour)
    return(freq_dic)

# %%
c = countFreq(hours)
c
# Out:
# {20: 3698,
#  21: 4267,
#  9: 2480,
#  14: 2585,
#  19: 3367,
#  12: 2455,
#  23: 4247,
#  17: 2920,
#  16: 2653,
#  8: 2154,
#  22: 4685,
#  4: 525,
#  15: 2691,
#  1: 2225,
#  7: 1461,
#  13: 2459,
#  0: 3329,
#  18: 3082,
#  11: 2527,
#  3: 786,
#  2: 1409,
#  6: 826,
#  10: 2565,
#  5: 550}

# %%
from sortedcontainers import SortedDict
sort_hours = SortedDict(c)
sort_hours
# Out:
# SortedDict({0: 3329, 1: 2225, 2: 1409, 3: 786, 4: 525, 5: 550, 6: 826, 7: 1461, 8: 2154, 9: 2480, 10: 2565, 11: 2527, 12: 2455, 13: 2459, 14: 2585, 15: 2691, 16: 2653, 17: 2920, 18: 3082, 19: 3367, 20: 3698, 21: 4267, 22: 4685, 23: 4247})

# %%
x = list(sort_hours.keys())
y = list(sort_hours.values())
plt.bar(x = x, height = y, edgecolor = "black", tick_label = x)
plt.title("Most Frequent log-in Hours for Users")
plt.tight_layout()

# %% [markdown]
# ## Analyze Information:
# - Dates
#     - Most Frequent months
#     - Most Frequent Weekday
# - Times
#     - Which 1/3 of the Day is most popular: Morning, Afternoon, Evening
#     - Popular time by the hour

# %%
dates = dt_table.Date
(unq_date, date_count) = np.unique(dates, return_counts = True)
unique_dates = np.asarray((unq_date, date_count)).T
unique_dates[:25]
# Out:
# array([[datetime.date(2011, 6, 27), 24],
#        [datetime.date(2011, 6, 28), 16],
#        [datetime.date(2011, 6, 29), 22],
#        [datetime.date(2011, 6, 30), 23],
#        [datetime.date(2011, 7, 1), 27],
#        [datetime.date(2011, 7, 2), 12],
#        [datetime.date(2011, 7, 3), 18],
#        [datetime.date(2011, 7, 4), 22],
#        [datetime.date(2011, 7, 5), 27],
#        [datetime.date(2011, 7, 6), 23],
#        [datetime.date(2011, 7, 7), 17],
#        [datetime.date(2011, 7, 8), 20],
#        [datetime.date(2011, 7, 9), 24],
#        [datetime.date(2011, 7, 10), 28],
#        [datetime.date(2011, 7, 11), 21],
#        [datetime.date(2011, 7, 12), 15],
#        [datetime.date(2011, 7, 13), 21],
#        [datetime.date(2011, 7, 14), 26],
#        [datetime.date(2011, 7, 15), 14],
#        [datetime.date(2011, 7, 16), 14],
#        [datetime.date(2011, 7, 17), 14],
#        [datetime.date(2011, 7, 18), 16],
#        [datetime.date(2011, 7, 19), 25],
#        [datetime.date(2011, 7, 20), 17],
#        [datetime.date(2011, 7, 21), 22]], dtype=object)

# %%
dt = pd.DataFrame(unique_dates, columns = ['Dates', 'Frequency'])

# %% [markdown]
# ### Datetime Table sorted from Past to most Recent

# %%
dt_order = dt.sort_values(by = 'Dates', ascending = True) #Dates from past to most recent
dt_order
# Out:
#           Dates Frequency
# 0    2011-06-27        24
# 1    2011-06-28        16
# 2    2011-06-29        22
# 3    2011-06-30        23
# 4    2011-07-01        27
# ..          ...       ...
# 366  2012-06-27      2743
# 367  2012-06-28      3981
# 368  2012-06-29      8441
# 369  2012-06-30     13754
# 370  2012-07-01      2090
#
# [371 rows x 2 columns]

# %%
plt.plot_date(x = dt_order['Dates'], y = dt_order['Frequency'])
plt.xlabel('Dates')
plt.ylabel('Last-Online Frequency')
plt.title("Last-Online Frequency by Date")
# Out:
# Text(0.5, 1.0, 'Last-Online Frequency by Date')

# %% [markdown]
# ## Datetime Table sorted by most Frequent dates users logged-on:
# - *Find the table values to be consistent with the graph shown above!*

# %%
dt.sort_values(by = 'Frequency', ascending = False).reset_index(drop = True) #Freq from HIGH to Low
# Out:
#           Dates Frequency
# 0    2012-06-30     13754
# 1    2012-06-29      8441
# 2    2012-06-28      3981
# 3    2012-06-27      2743
# 4    2012-07-01      2090
# ..          ...       ...
# 366  2011-07-17        14
# 367  2011-08-12        14
# 368  2011-09-08        13
# 369  2011-09-01        12
# 370  2011-07-02        12
#
# [371 rows x 2 columns]

# %% [markdown]
# ### Explore the Growth stage of the dates

# %%
low_freq_dt = dt_order[0:355]
low_freq_dt
plt.plot_date(x = low_freq_dt['Dates'], y = low_freq_dt['Frequency'])
plt.xlabel('Dates')
plt.ylabel('Last-Online Frequency')
plt.title("Last-Online Frequency by Date")
# Out:
# Text(0.5, 1.0, 'Last-Online Frequency by Date')

# %% [markdown]
# # EssayQuestions include:
# - essay0 - My self summary
# - essay1 - What I’m doing with my life
# - essay2 - I’m really good at
# - essay3 - The first thing people usually notice about me
# - essay4 - Favorite books, movies, show, music, and food
# - essay5 - The six things I could never do without
# - essay6 - I spend a lot of time thinking about
# - essay7 - On a typical Friday night I am
# - essay8 - The most private thing I am willing to admit
# - essay9 - You should message me if…

# %% [markdown]
# ## Correlation Matrix between Numerical Features

# %%
corr = df_copy.corr()
ax = sns.heatmap(corr, vmin = -1, vmax= 1, center = 0, cmap = sns.diverging_palette(20,220, n=200), square = True)
ax.set_xticklabels(
    ax.get_xticklabels(), rotation= 45, horizontalalignment = 'right'
)
# Out:
# [Text(0.5, 0, 'age'), Text(1.5, 0, 'height'), Text(2.5, 0, 'income')]

# %% [markdown]
# ## EDA Bar charts for certain features

# %%
plt.title('Ages of Survey Respondants')
plt.hist(df_copy.age, bins = 30)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.xlim(16,70)

# plt.boxplot(df_copy.age)
plt.show()

# %%
plt.hist(df_copy.sex, bins = 2, align = 'mid')
plt.xlabel('sex')
plt.ylabel('freq')
plt.title('Distribution of Male and Female participants')
plt.show()

# %%
plt.hist(df_copy.orientation, bins = 3)
plt.xlabel('orientation')
plt.ylabel('Frequency')
plt.title('Distribution of Sexual Orientation in Data')
plt.tight_layout()
plt.show()

# %%
plt.hist(df_copy.location, bins = 20, orientation = 'vertical')
plt.xlabel('locations')
plt.ylabel('freq')
plt.title('Frequency of Responses based on Location')
# plt.xticks(rotation = 'vertical')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Features to still synthesize:
# - Education
# - Job
# - Religion
# - Pets
# - Sign/ Zodiac
# - Status

# %%
df_copy['education'].nunique()

# %%
unique_edu = df_copy['education'].unique()
unique_edu

# %% [markdown]
# ## Create a dictionary that maps the 32 different education features to 4:
# - Graduated High School
# - Graduated College/ University
# - Graduated Masters or PhD program
# - Other

# %%
loc_data = df_copy.groupby(['location', 'sex'])['sex'].count().sort_values(ascending = False)
print(loc_data.head(60))
loc_data.to_frame()
print(loc_data['sex'])
location_data = df_copy.groupby(['location'])['sex'].count().sort_values(ascending = False)

# %%
df_copy['ethnicity'].unique()
df_copy['ethnicity'].dropna()

# %%
df_copy['ethnicity'].nunique()

# %%
df_copy['status'].unique()

# %%
plt.rcParams['figure.figsize'] = [20,20]
plt.rcParams['axes.labelsize'] = 50
plt.rcParams['xtick.direction'] = 'inout'
plt.rcParams['legend.fontsize'] = 25
for i in init_drop_cols:
    df_copy[init_drop_cols][i].hist()
plt.tight_layout()
plt.legend(init_drop_cols)
# df_copy['offspring'].hist()

# %%
df_copy.diet.value_counts()

# %%
df_copy.drugs.value_counts()

# %%
df_copy.drinks.value_counts()

# %%
df_copy.education.value_counts()
# edu_table = pd.DataFrame(['In School', 
#                           'Graduated', 
#                           ''])

# %%
df_copy.ethnicity.value_counts()

# %%
df_copy.income.value_counts()

# %%
df_copy.job.value_counts()

# %%
df_copy.last_online.value_counts().head(50)

# %%
df_copy.location.value_counts().head(50)
# df_copy.location.value_counts().head(50).sum()

# %%
df_copy.pets.value_counts(dropna = False)

# %%
zodiac_table = pd.DataFrame(columns = ['Leo',
                                       'Libra', 
                                       'Cancer', 
                                       'Virgo', 
                                       'Scorpio', 
                                       'Gemini', 
                                       'Taurus', 
                                       'Aries', 
                                       'Piscs', 
                                       'Aquarius', 
                                       'Sagittarius', 
                                       'Capricorn', 
                                       'Matters'])
#Matters is a boolean value of 1 or 0 -- Y or N

# %%
df_copy.sign.value_counts(dropna = False) #44 value_counts /48

# %%
zodiac_dict = {'leo': 0, 'libra': 0, 'cancer': 0, 'virgo': 0, 'scorpio': 0, 'gemini': 0, 'taurus': 0, 'aries': 0, 'pisces': 0, 'aquarius': 0, 'sagittarius': 0, 'capricorn': 0}

# %% [markdown]
# ### Formulate a Question
# df.sign.value_counts()
#
# ** Still have to drop na values for features + drop some features themselves

# %% [markdown]
# ### Augment Your data - by mapping categorical data -> numerical
#
# done to drinks, smokes, and drugs columns
#
#  drink_mapping = {"not at all": 0, "rarely": 1, "socially": 2, "often": 3, "very often": 4, "desperately": 5}
#
# all_data["drinks_code"] = all_data.drinks.map(drink_mapping)

# %%
location_names = df_copy.groupby(['location']).groups
print(location_names.items())

# %%
locations = df_copy.groupby(['location', 'sex'], as_index = False).count()
print(locations)

# %% [markdown]
# ### Calculate how many locations are in california and otherwise

# %%
location_frame = df_copy.location.to_frame()
print(type(df_copy))
# for i in range(len(location_frame)):
#     cali_count = 0
#     other = 0
#     if location_frame.str.contains(', california', na = False):
#         cali_count += 1
#     else:
#         other += 1
# print(cali_count)

# %%
print(location_data_total)

# %%
location_labels = df_copy.groupby(['location'])['sex']
print(location_labels)

# %%
plt.pie(location_data, autopct = '%d%%')
plt.legend(location_data)
plt.show()
